# %%
## El petróleo en el Ecuador

# %%
print('La confirmación de la existencia de petróleo crudo en el Ecuador se dio en 1911 con la perforación del primer pozo Ancón 1, en la península de Santa Elena, y más tarde, en 1967, con la perforación del pozo Lago Agrio 1, en la Amazonía, a cargo de la operadora Texaco Gulf. La actual empresa petrolera del Ecuador, EP Petroecuador, es resultado de estos y otros descubrimientos petrolíferos')
# Out:
# La confirmación de la existencia de petróleo crudo en el Ecuador se dio en 1911 con la perforación del primer pozo Ancón 1, en la península de Santa Elena, y más tarde, en 1967, con la perforación del pozo Lago Agrio 1, en la Amazonía, a cargo de la operadora Texaco Gulf. La actual empresa petrolera del Ecuador, EP Petroecuador, es resultado de estos y otros descubrimientos petrolíferos

# %%
### la Amazonía ecuatoriana, el territorio en el que Ecuador obtienes la mayor parte de su petróleo
![Imagen](

# %%
## Producción petrolera ecuatoriana 2015-2020

# %%
import matplotlib.pyplot as plt
etiquetas=['2017','2018','2019','2020']
valores=[543,548, 320,517]
plt.title('Producción petróleo Ecuador')
plt.bar(etiquetas, valores)
plt.xlabel('Años')
plt.ylabel('miles de barriles')
plt.show()
